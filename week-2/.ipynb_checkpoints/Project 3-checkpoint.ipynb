# %%
def display_student_data():
    # names
    girls_names = ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
    girls_ages = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
    girls_heights = [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
    girls_scores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

    boys_names = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]
    boys_ages = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
    boys_heights = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
    boys_scores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

    #into tuple
    students = []
    
    # Adding
    for i in range(len(girls_names)):
        students.append((girls_names[i], girls_ages[i], girls_heights[i], girls_scores[i], "Girl"))
        
    # Adding
    for i in range(len(boys_names)):
        students.append((boys_names[i], boys_ages[i], boys_heights[i], boys_scores[i], "Boy"))

    print(f"{'Name':<12} | {'Age':<5} | {'Height':<8} | {'Score':<5} | {'Gender':<6}")
    print("-" * 50)


    for name, age, height, score, gender in students:
        print(f"{name:<12} | {age:<5} | {height:<8} | {score:<5} | {gender:<6}")

# Execute the program
display_student_data()
# Out:
# Name         | Age   | Height   | Score | Gender
# --------------------------------------------------
# Evelyn       | 17    | 5.5      | 80    | Girl
# Jessica      | 16    | 6.0      | 85    | Girl
# Somto        | 17    | 5.4      | 70    | Girl
# Edith        | 18    | 5.9      | 60    | Girl
# Liza         | 16    | 5.6      | 76    | Girl
# Madonna      | 18    | 5.5      | 66    | Girl
# Waje         | 17    | 6.1      | 87    | Girl
# Tola         | 20    | 6.0      | 95    | Girl
# Aisha        | 19    | 5.7      | 50    | Girl
# Latifa       | 17    | 5.5      | 49    | Girl
# Chinedu      | 19    | 5.7      | 74    | Boy
# Liam         | 16    | 5.9      | 87    | Boy
# Wale         | 18    | 5.8      | 75    | Boy
# Gbenga       | 17    | 6.1      | 68    | Boy
# Abiola       | 20    | 5.9      | 66    | Boy
# Kola         | 19    | 5.5      | 78    | Boy
# Kunle        | 16    | 6.1      | 87    | Boy
# George       | 18    | 5.4      | 98    | Boy
# Thomas       | 17    | 5.8      | 54    | Boy
# Wesley       | 19    | 5.7      | 60    | Boy
